# %%
# !pip install matplotlib --upgrade

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from statistics import mean

# %%
# random distribution of booters benign
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
client1 = [98,83,100,99,100,81,82,99,100,81,82,98,99,99,98,97,100,99,99,82]
client2 = [83,83,83,81,82,83,84,92,82,82,82,99,81,83,82,99,99,83,83,99]
client3 = [99,82,81,95,99,81,81,97,99,100,100,81,100,93,100,81,99,99,100,100]
client4 = [98,81,99,94,100,100,96,83,81,98,81,91,99,89,83,95,80,92,79,99]
client5 = [81,97,98,98,91,99,99,81,99,90,93,98,100,96,82,97,95,81,92,82]
client6 = [99,98,100,99,86,81,81,100,99,99,88,99,90,81,89,81,99,99,99,82]
client7 = [83,83,83,83,83,83,83,83,91,82,83,83,83,83,83,83,83,81,83,86]
FL = [100,100,99,100,100,99,100,100,100,100,99,99,92,100,100,100,100,100,82,100]
langs = ['client1', 'client2', 'client3', 'client4', 'client5', 'client6', 'client7','FL']
clients = [mean(client1),mean(client2),mean(client3),mean(client4),mean(client5),mean(client6),mean(client7),mean(FL)]
ax.set_title('Average true negative rate (benign traffic)')
ax.set_ylabel('accuracy %')
plt.rc('font', size=11)
ax.bar(langs,clients,color=['tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:orange'])
plt.ylim(top=100)
plt.show()

# %%
# random distribution of booters attack
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
client1 = [98.3,99,93.5,93.5,98.3,56.6,98.8,98.3,46.2,92.6,93,35.7,93.3,95.5,96.3,95.5,92.5,98.3,98.3,96.1]
client2 = [20,99.3,93.1,99.8,42.3,98.8,99.3,95.6,99.3,99,87,98.3,94.8,99.3,99.3,98.3,98.5,99,93.8,98.8]
client3 = [98.5,89.6,63.6,46.6,98.3,94,99,98.3,93.5,95.5,98.5,29.3,95.3,95.6,98.1,71,85.6,46.5,98.3,83.5]
client4 = [98.3,86,83.3,96.1,95.5,92.6,92.6,25.5,85.6,98.1,96,95.1,95.3,95.6,25.5,98.3,87,98.3,93.6,93.3]
client5 = [93.1,92.8,98.1,95.5,93.3,98.5,98.5,26.6,98.1,92.6,86.6,98.3,25,25,26.6,86.8,83.1,95.8,95.5,26.5]
client6 = [92.8,96,96.1,98.5,40.3,99.3,96.6,98.5,98.3,95.3,98.3,98.3,98.5,94.1,95.5,96.8,98.3,95.3,83.8,47.3]
client7 = [93.8,99,94,98.8,98.8,98.8,94,99,93.5,94.3,98.8,96,93.5,96,93.8,84,98.8,30.5,99.1,93.3]
FL = [93.4,92.2,92.2,92.9,93.2,86.4,92.4,92.5,93.2,93.5,90,93.2,91,93.2,93.2,86,93.5,93.2,93,90.7]
langs = ['client1', 'client2', 'client3', 'client4', 'client5', 'client6', 'client7', 'FL']
clients = [mean(client1),mean(client2),mean(client3),mean(client4),mean(client5),mean(client6),mean(client7),mean(FL)]
ax.set_title('Average true positive rate (attack traffic)')
ax.set_ylabel('accuracy %')
plt.ylim(top=100)
plt.rc('font', size=11)
ax.bar(langs,clients,color=['tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:orange'])
plt.show()

# %%
# trust effect
labels = ['true negative rate (benign)', 'true positive rate (attacks)']
nontrusted7 = [81, 99.5]
nontrusted14 = [81, 99.5]
nontrusted21 = [84, 93.7]
trusted7 = [100, 95.4]
trusted14 = [100, 93.4]
trusted21 = [100, 93.2]
x = np.arange(len(labels))  # the label locations
width = 0.28  # the width of the bars
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
rects1 = ax.bar(x - width/2, nontrusted21, width, label='Non-trusted')
rects2 = ax.bar(x + width/2, trusted21, width, label='Trusted')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('accuracy %')
ax.set_title('Trust effect on FedAvg')
ax.set_xticks(x, labels)
ax.legend(loc=9, bbox_to_anchor=(0.5, 1))
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
plt.rc('font', size=11)
#fig.tight_layout()
plt.show()

# %%
#fig = plt.figure()
fig = plt.figure(figsize=(12,5))
#fig = plt.figure(figsize=(15,6))
ax = fig.add_axes([0,0,1,1])
langs7 = ['client1', 'client2', 'client3', 'client4', 'client5', 'client6', 'client7',
          'FL']
clients7 = [95,99,98,90,83,83,98,
            100]
color7 = ['tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:orange']
langs14 = ['client1', 'client2', 'client3', 'client4', 'client5', 'client6', 'client7',
           'client8', 'client9', 'client10', 'client11', 'client12', 'client13', 'client14',
           'FL']
clients14 = [98,99,98,90,83,83,85,
             81,99,99.5,81,81,83,100,
             100]
color14 = ['tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:orange']
langs21 = ['client1', 'client2', 'client3', 'client4', 'client5', 'client6', 'client7',
           'client8', 'client9', 'client10', 'client11', 'client12', 'client13', 'client14',
           'client15', 'client16', 'client17', 'client18', 'client19', 'client20', 'client21',
           'FL']
clients21 = [90,92,95,91,82,98,92,
             93,99,90,91,89,81,88,
             99,99,98,99,82,99,93,
             100]
color21 = ['tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:orange']
ax.set_title('True negative rate (benign traffic)')
ax.set_ylabel('accuracy %')
plt.rc('font', size=13)
plt.rc('xtick', labelsize=12)
ax.bar(langs14,clients14,color=color14)
plt.ylim(top=100)
plt.show()

# %%
#fig = plt.figure()
fig = plt.figure(figsize=(12,5))
#fig = plt.figure(figsize=(15,6))
ax = fig.add_axes([0,0,1,1])
langs7 = ['client1', 'client2', 'client3', 'client4', 'client5', 'client6', 'client7',
          'FL']
clients7 = [93.5,98,98.33,86.56,85.66,98,92.5,
            98.33]
color7 = ['tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:orange']
langs14 = ['client1', 'client2', 'client3', 'client4', 'client5', 'client6', 'client7',
           'client8', 'client9', 'client10', 'client11', 'client12', 'client13', 'client14',
           'FL']
color14 = ['tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:orange']
clients14 = [93.5,96.5,96.5,86.56,85.66,99,96,
             99,96.5,93.5,93,71,96.3,92.3,
             94.8]
langs21 = ['client1', 'client2', 'client3', 'client4', 'client5', 'client6', 'client7',
           'client8', 'client9', 'client10', 'client11', 'client12', 'client13', 'client14',
           'client15', 'client16', 'client17', 'client18', 'client19', 'client20', 'client21',
           'FL']
clients21 = [94,99,98.5,92,86,98.5,97,
             99,99,93.5,93,91,93,95,
             84,92,98,87,86,94,92,
             96]
color21 = ['tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:blue','tab:orange']
ax.set_title('True positive rate (booter attacks)')
ax.set_ylabel('accuracy %')
plt.ylim(top=100)
plt.rc('font', size=13)
plt.rc('xtick', labelsize=12)
ax.bar(langs14,clients14,color=color14)
plt.show()
